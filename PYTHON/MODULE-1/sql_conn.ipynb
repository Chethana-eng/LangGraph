# %%
# !pip install pymysql
# Out:
# ...
#    ---------------------------------------- 0.0/45.7 kB ? eta -:--:--
#    ---------------------------------------- 45.7/45.7 kB 2.4 MB/s eta 0:00:00
# ...

# %%
# !pip install mysql-connector-python
# Out:
# ...
#    ---------------------------------------- 0.0/17.7 MB ? eta -:--:--
#    ---------------------------------------- 0.1/17.7 MB 3.6 MB/s eta 0:00:05
#     --------------------------------------- 0.2/17.7 MB 3.0 MB/s eta 0:00:06
#     --------------------------------------- 0.4/17.7 MB 3.3 MB/s eta 0:00:06
#    - -------------------------------------- 0.5/17.7 MB 2.6 MB/s eta 0:00:07
#    - -------------------------------------- 0.7/17.7 MB 3.2 MB/s eta 0:00:06
#    - -------------------------------------- 0.8/17.7 MB 3.2 MB/s eta 0:00:06
#    -- ------------------------------------- 1.0/17.7 MB 2.9 MB/s eta 0:00:06
#    -- ------------------------------------- 1.1/17.7 MB 3.0 MB/s eta 0:00:06
#    -- ------------------------------------- 1.2/17.7 MB 2.9 MB/s eta 0:00:06
#    --- ------------------------------------ 1.4/17.7 MB 3.0 MB/s eta 0:00:06
#    --- ------------------------------------ 1.5/17.7 MB 2.9 MB/s eta 0:00:06
# ...

# %%
import pymysql
